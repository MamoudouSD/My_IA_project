# %%
# ===========================================================================
# DIANI Mamoudou Sékou
#
# Septembre 2023
#===========================================================================

# %%
# Importation des bibliothèques nécessaires
import pandas as pd
import numpy as np
import wfdb
import ast
from scipy import stats
from keras.models import Model
from keras.models import Sequential
from keras.layers import Conv1D, Conv2D, MaxPooling2D, Add, MaxPooling1D, Input, BatchNormalization, UpSampling2D, Activation, Dropout, Flatten, Dense, Lambda, Concatenate, GlobalAveragePooling1D
from keras import backend
from keras.callbacks import CSVLogger, ModelCheckpoint, EarlyStopping
from tensorflow.keras.optimizers import Adam
from keras import backend as K
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc
import matplotlib.pyplot as plt
from math import sqrt
from keras.models import load_model
from keras import Model
import pywt

# Importation des bibliothèques nécessaires pour le traitement d'images avec TensorFlow et Keras
import tensorflow as tf
tf.debugging.set_log_device_placement(False)
from keras.preprocessing.image import ImageDataGenerator

# Utilisation du module XLA pour accelerer les calculs
from tensorflow._api.v2.compat.v1 import xla

# %%
# Cette fonction charge les données brutes à partir des fichiers ECG en utilisant la bibliothèque wfdb.
# Elle prend en parametre le dataFrame contenant les informations sur les fichiers, le taux d'échantillonnage des signaux
# Le chemin vers le répertoire contenant les fichiers et renvoie un tableau contenant les signaux bruts.
def load_raw_data(df, sampling_rate, path):
    if sampling_rate == 100:
        data = [wfdb.rdsamp(path+f) for f in df.filename_lr]
    else:
        data = [wfdb.rdsamp(path+f) for f in df.filename_hr]
    data = np.array([signal for signal, meta in data])
    return data

# Chemin vers le répertoire contenant les fichiers
path = '/Users/mamoudousdiani/Documents/UQAM/projet_master/Base_de_donnee/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'

# Taux d'échantillonnage
sampling_rate=100

# Chargement et convertion des données d'annotation
Y = pd.read_csv(path+'ptbxl_database.csv', index_col='ecg_id')
Y.scp_codes = Y.scp_codes.apply(lambda x: ast.literal_eval(x))

# # Chargement des données brutes des signaux
X = load_raw_data(Y, sampling_rate, path)

# Chargement de scp_statements.csv pour l'agrégation diagnostique
agg_df = pd.read_csv(path+'scp_statements.csv', index_col=0)
agg_df = agg_df[agg_df.diagnostic == 1]


# Cette fonction agrège les diagnostics en utilisant le fichier scp_statements.csv
# Elle prend comme parametre un dictionnaire contenant les codes de diagnostic
# Et renvoie la liste des classes diagnostiques agrégées
# La fonction parcourt les clés du dictionnaire (y_dic) et vérifie si chaque 
# clé existe dans le fichier scp_statements.csv (représenté par le DataFrame agg_df).
# Si la clé existe, la fonction ajoute la classe diagnostique correspondante à la liste temporaire.
# Enfin, la fonction utilise un ensemble (set) pour éliminer les doublons, puis convertit cet ensemble en liste et la renvoie.
def aggregate_diagnostic(y_dic):
    tmp = []
    for key in y_dic.keys():
        if key in agg_df.index:
            tmp.append(agg_df.loc[key].diagnostic_class)
    return list(set(tmp))

# Appliquation de la superclasse diagnostique
Y['diagnostic_superclass'] = Y.scp_codes.apply(aggregate_diagnostic)

# Séparation des données en ensembles d'entraînement, de validation et de test
test_fold = 9
# Train
X_train1 = X[np.where(Y.strat_fold < test_fold)]
y_train1 = Y[(Y.strat_fold < test_fold)].diagnostic_superclass
# validation
X_val1 = X[np.where(Y.strat_fold == test_fold)]
y_val1 = Y[Y.strat_fold == test_fold].diagnostic_superclass
# Test
X_test1 = X[np.where(Y.strat_fold > test_fold)]
y_test1 = Y[Y.strat_fold > test_fold].diagnostic_superclass

# %%
# Cette fonction convertit les codes de diagnostic en un tableau de classe diagnostique.
# Elle prend en paramètre X un dictionnaire contenant les codes de diagnostic pour un enregistrement ECG
# et renvoie un Tableau de classe diagnostique encodé, la liste des indices des diagnostics valides.
# et la liste des indices des diagnostics non valides
def convY(x):
    a=x.keys()
    d=[]
    listeV=[]
    listeNV=[]
    lv=0
    N=0
    M=0
    S=0
    C=0
    H=0
    bof=0
    for i in range(len(a)):
        if 'NORM' in x[a[i]]:
            d.append([1, 0, 0, 0, 0])
            #listeV.append(i)
            N=N+1
        elif 'MI' in x[a[i]]:
            d.append([0, 1, 0, 0, 0])
            listeV.append(i)
            M=M+1
        elif 'STTC' in x[a[i]]:
            d.append([0, 0, 1, 0, 0])
            listeV.append(i)
            S=S+1
        elif 'CD' in x[a[i]]:
            d.append([0, 0, 0, 1, 0])
            listeV.append(i)
            C=C+1
        elif 'HYP' in x[a[i]]:
            d.append([0, 0, 0, 0, 1])
            listeV.append(i)
            H=H+1
        else:
            d.append([0, 0, 0, 0, 0])
            listeNV.append(i)
            bof=bof+1
        lv=lv+1

    d= np.array(d)
    print(N,M,S,C,H,bof)
    return d, listeV, listeNV


# Cette fonction calcule la moyenne et l'écart type des valeurs dans une liste tridimensionnelle
# Elle prend en paramètre une liste tridimensionnelle contenant les valeurs
# Elle retourne la moyenne et l'ecart type des valeurs
def calcul(X_train):
    a=0
    nb=0
    for i in range(len(X_train)):
        for j in range(len(X_train[i])):
            for k in range(len(X_train[i][j])):
                a=a+X_train[i][j][k]
                nb=nb+1
    moy=a/nb
    b=0
    for i in range(len(X_train)):
        for j in range(len(X_train[i])):
            for k in range(len(X_train[i][j])):
                b=b+((X_train[i][j][k]-moy)**2)
    ecT=sqrt(b/nb)
    return moy, ecT


# Cette fonction normalise une liste tridimensionnelle en utilisant la moyenne et l'écart type.
# Elle prend en paramètre une liste tridimensionnelle à normaliser, la moyenne des valeurs utilisée pour la normalisation
# l'ecart type des valeurs utilisé pour la normalisation.
# Elle retourne une liste tridimensionnelle normalisée.
def normalisation(l,moy, ecT):
    for i in range(len(l)):
        for j in range(len(l[i])):
            for k in range(len(l[i][j])):
                l[i][j][k] = (l[i][j][k]-moy)/(ecT)
    return l


# Cette fonction supprime les éléments non valides (pas de classe) d'une liste 
# en utilisant la liste des indices des diagnostics non valides.
# Elle prend en paramètre X_train et y_train les listes de signaux et de leures classes 
# lnv la liste contenant les indices des éléments non valides
# Elle retourne les liste contenant les éléments valides correspondant aux indices fournis
def dataConcr(X_train, y_train, lnv):
    dataX=[]
    dataY=[]
    for i in range(len (X_train)):
        if i not in lnv:
            dataX.append(X_train[i])
            dataY.append(y_train[i])

    return (stats.zscore(np.array(dataX)), np.array(dataY))


# Cette fonction transpose une matrice x (une liste de listes) en intervertissant ses lignes et colonnes. 
# Elle prend en parametre x une liste de matrice
# et retourne cette meme matrice transforme
def transform1(x):
    return [[row[i] for row in x] for i in range(len(x[0]))]


# Cette fonction transpose une matrice x (une liste de listes) en intervertissant ses lignes et colonnes. 
# Elle prend en parametre x une liste de matrice
# et retourne cette meme matrice transforme
def transform1inverse(x):
    return [[x[j][i] for j in range(len(x))] for i in range(len(x[0]))]


# Cette fonction applique la transformée en ondelettes discrètes (DWT) à chaque colonne du signal x 
# Elle prend en parametre x une matrice et une famille d'ondelettes spécifiée par fam.
# Elle retourne une matrice de coefficient 
def signalDWT(x, fam):
    sortie=[]
    a= transform1(x)
    for i in range (len(a)):
        cA, _=pywt.dwt(a[i], fam)
        sortie.append(cA)
    x=transform1inverse(sortie)
    return np.array(x)


# Cette fonction permet de faire une DWT sur tout les signaux en appelant signalDWT
def recupDWT(x, fam):
    test=[]
    for i in range (len(x)):
        test.append(signalDWT(x[i], fam))
    return np.array(test)

# %%
# Convertir les labels de la classe en vecteurs binaires
y_train, lv_train, lnv_train = convY(y_train1)
y_val, lv_val, lnv_val=convY(y_val1)
y_test, lv_test, lnv_test=convY(y_test1)

# Traitement des données d'entraînement
X_train, y_train=dataConcr(X_train1, y_train, lnv_train)
X_val, y_val=dataConcr(X_val1, y_val, lnv_val)
X_test, y_test=dataConcr(X_test1, y_test, lnv_test)


# Conversion des donnees en coefficient de DWT et normalisation
X_train=recupDWT(X_train, 'db4')
X_train=stats.zscore(X_train)
X_test=recupDWT(X_test, 'db4')
X_test=stats.zscore(X_test)
X_val=recupDWT(X_val, 'db4')
X_val=stats.zscore(X_val)

# %%
# Créer un objet d'entrée pour le modèle
input_layer = Input(shape=(503, 12))

# %%
# Création d'une architecture pour l'extraction des caractéristiques à partir de séquences temporelles 1D.
def feature_extraction(input):
    x = Conv1D(64, 3)(input) 
    x = Activation("relu")(x)
    x = BatchNormalization()(x)

    x = Conv1D(128, 3)(x) 
    x = Activation("relu")(x)
    x = BatchNormalization()(x)

    x = Conv1D(64, 7)(x) 
    x = Activation("relu")(x)
    x = BatchNormalization()(x)

    x1 = Conv1D(64, 3)(input) 
    x1 = Activation("relu")(x1)
    x1 = BatchNormalization()(x1)

    x1 = Conv1D(128, 3)(x1) 
    x1 = Activation("relu")(x1)
    x1 = BatchNormalization()(x1)

    x1 = Conv1D(64, 7)(x1) 
    x1 = Activation("relu")(x1)
    x1 = BatchNormalization()(x1)

    X2 = Add()([x, x1])
    x2 = Activation('relu')(X2)
    
    x2 = Conv1D(32, 7)(x2) 
    x2 = Activation("relu")(x2)
    x2= Dropout(0.5)(x2)
    return x2


# Partie completement connectee (Fully Connected Layer) pour la classification multiclasse.
def fully_connected(encoded):
    x = Flatten()(encoded)
    x = Dense(5)(x)
    sortie = Activation('softmax')(x)
    return sortie

# Declaration du modele:
model = Model(img_input, fully_connected(feature_extraction(img_input)))

# Affichage des parametres du modele
model.summary()

# Compilation du modele en definissant la fonction de perte, l'optimisateur et la valeur afficher durant l'entrainement
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Sauvegarde du modèle ayant le meilleur val_accuracy pendant l'entraînement dans Model.hdf5. 
modelsPath = "Model.hdf5"
modelcheckpoint = ModelCheckpoint(filepath=modelsPath,
                                  monitor='val_accuracy', verbose=1, save_best_only=True, mode='auto')
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 503, 12)]            0         []
#
#  conv1d_7 (Conv1D)           (None, 501, 128)             4736      ['input_2[0][0]']
#
#  conv1d_10 (Conv1D)          (None, 501, 128)             4736      ['input_2[0][0]']
#
#  activation_9 (Activation)   (None, 501, 128)             0         ['conv1d_7[0][0]']
#
#  activation_12 (Activation)  (None, 501, 128)             0         ['conv1d_10[0][0]']
#
#  batch_normalization_6 (Bat  (None, 501, 128)             512       ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 501, 128)             512       ['activation_12[0][0]']
#  chNormalization)
#
#  conv1d_8 (Conv1D)           (None, 499, 64)              24640     ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv1d_11 (Conv1D)          (None, 499, 64)              24640     ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  activation_10 (Activation)  (None, 499, 64)              0         ['conv1d_8[0][0]']
#
#  activation_13 (Activation)  (None, 499, 64)              0         ['conv1d_11[0][0]']
#
#  batch_normalization_7 (Bat  (None, 499, 64)              256       ['activation_10[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 499, 64)              256       ['activation_13[0][0]']
#  tchNormalization)
#
#  conv1d_9 (Conv1D)           (None, 497, 64)              12352     ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  conv1d_12 (Conv1D)          (None, 497, 64)              12352     ['batch_normalization_10[0][0]
#                                                                     ']
#
#  activation_11 (Activation)  (None, 497, 64)              0         ['conv1d_9[0][0]']
#
#  activation_14 (Activation)  (None, 497, 64)              0         ['conv1d_12[0][0]']
#
#  batch_normalization_8 (Bat  (None, 497, 64)              256       ['activation_11[0][0]']
#  chNormalization)
#
#  batch_normalization_11 (Ba  (None, 497, 64)              256       ['activation_14[0][0]']
#  tchNormalization)
#
#  add_1 (Add)                 (None, 497, 64)              0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_11[0][0
#                                                                     ]']
#
#  activation_15 (Activation)  (None, 497, 64)              0         ['add_1[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 495, 64)              12352     ['activation_15[0][0]']
#
#  activation_16 (Activation)  (None, 495, 64)              0         ['conv1d_13[0][0]']
#
#  dropout_1 (Dropout)         (None, 495, 64)              0         ['activation_16[0][0]']
#
#  flatten_1 (Flatten)         (None, 31680)                0         ['dropout_1[0][0]']
#
#  dense_1 (Dense)             (None, 5)                    158405    ['flatten_1[0][0]']
#
#  activation_17 (Activation)  (None, 5)                    0         ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 256261 (1001.02 KB)
# Trainable params: 255237 (997.02 KB)
# Non-trainable params: 1024 (4.00 KB)
# __________________________________________________________________________________________________

# %%
# entrainement du modele
classifier = model.fit(X_train, y_train,
                       epochs=25, # nombre d' poques
                       batch_size=90, # nombre d'images entrain es ensemble
                       validation_data=(X_val, y_val), # donn es de validation
                       verbose=1, # mets cette valeur   0, si vous voulez ne pas afficher les d tails d'entrainement
                       callbacks=[modelcheckpoint], # les fonctions   appeler   la fin de chaque  poque (dans ce cas modelcheckpoint: qui sauvegarde le mod le)
                       shuffle=True)# shuffle les images 

# ==========================================
# ========AFFICHAGE DES RESULTATS===========
# ==========================================

# Plot accuracy over epochs (precision par  poque)
print(classifier.history.keys())
plt.plot(classifier.history['accuracy'])
plt.plot(classifier.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'])
fig = plt.gcf()
plt.show()
# Out:
# Epoch 1/25
# 2023-09-21 12:26:46.810472: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 190/190 [==============================] - ETA: 0s - loss: 0.1164 - accuracy: 0.6138
# 2023-09-21 12:27:00.482046: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# Epoch 1: val_accuracy improved from -inf to 0.64772, saving model to ModelPKM.hdf5
# 190/190 [==============================] - 15s 72ms/step - loss: 0.1164 - accuracy: 0.6138 - val_loss: 0.1027 - val_accuracy: 0.6477
# Epoch 2/25
#   2/190 [..............................] - ETA: 12s - loss: 0.0907 - accuracy: 0.6778
# /Users/mamoudousdiani/miniconda3/envs/tensorflow/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 190/190 [==============================] - ETA: 0s - loss: 0.0819 - accuracy: 0.7098
# Epoch 2: val_accuracy improved from 0.64772 to 0.70037, saving model to ModelPKM.hdf5
# 190/190 [==============================] - 13s 68ms/step - loss: 0.0819 - accuracy: 0.7098 - val_loss: 0.0870 - val_accuracy: 0.7004
# Epoch 3/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0696 - accuracy: 0.7616
# Epoch 3: val_accuracy improved from 0.70037 to 0.72460, saving model to ModelPKM.hdf5
# 190/190 [==============================] - 13s 70ms/step - loss: 0.0696 - accuracy: 0.7616 - val_loss: 0.0800 - val_accuracy: 0.7246
# Epoch 4/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.7893
# Epoch 4: val_accuracy improved from 0.72460 to 0.72880, saving model to ModelPKM.hdf5
# 190/190 [==============================] - 13s 68ms/step - loss: 0.0621 - accuracy: 0.7893 - val_loss: 0.0789 - val_accuracy: 0.7288
# Epoch 5/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0544 - accuracy: 0.8161
# Epoch 5: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0544 - accuracy: 0.8161 - val_loss: 0.0800 - val_accuracy: 0.7251
# Epoch 6/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0500 - accuracy: 0.8343
# Epoch 6: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0500 - accuracy: 0.8343 - val_loss: 0.0829 - val_accuracy: 0.7171
# Epoch 7/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0447 - accuracy: 0.8553
# Epoch 7: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0447 - accuracy: 0.8553 - val_loss: 0.0853 - val_accuracy: 0.7148
# Epoch 8/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0410 - accuracy: 0.8637
# Epoch 8: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 66ms/step - loss: 0.0410 - accuracy: 0.8637 - val_loss: 0.0894 - val_accuracy: 0.7130
# Epoch 9/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0375 - accuracy: 0.8806
# Epoch 9: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0375 - accuracy: 0.8806 - val_loss: 0.0858 - val_accuracy: 0.7283
# Epoch 10/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.8873
# Epoch 10: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0347 - accuracy: 0.8873 - val_loss: 0.0869 - val_accuracy: 0.7246
# Epoch 11/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0327 - accuracy: 0.8939
# Epoch 11: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 66ms/step - loss: 0.0327 - accuracy: 0.8939 - val_loss: 0.0850 - val_accuracy: 0.7241
# Epoch 12/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0301 - accuracy: 0.9042
# Epoch 12: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0301 - accuracy: 0.9042 - val_loss: 0.0873 - val_accuracy: 0.7260
# Epoch 13/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9096
# Epoch 13: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 67ms/step - loss: 0.0287 - accuracy: 0.9096 - val_loss: 0.0941 - val_accuracy: 0.7139
# Epoch 14/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0280 - accuracy: 0.9124
# Epoch 14: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 70ms/step - loss: 0.0280 - accuracy: 0.9124 - val_loss: 0.0911 - val_accuracy: 0.7162
# Epoch 15/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.9151
# Epoch 15: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 68ms/step - loss: 0.0267 - accuracy: 0.9151 - val_loss: 0.0895 - val_accuracy: 0.7251
# Epoch 16/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9194
# Epoch 16: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 13s 68ms/step - loss: 0.0255 - accuracy: 0.9194 - val_loss: 0.0942 - val_accuracy: 0.7195
# Epoch 17/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9170
# Epoch 17: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 15s 77ms/step - loss: 0.0259 - accuracy: 0.9170 - val_loss: 0.0906 - val_accuracy: 0.7199
# Epoch 18/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9268
# Epoch 18: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 15s 79ms/step - loss: 0.0238 - accuracy: 0.9268 - val_loss: 0.0925 - val_accuracy: 0.7185
# Epoch 19/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0229 - accuracy: 0.9285
# Epoch 19: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 75ms/step - loss: 0.0229 - accuracy: 0.9285 - val_loss: 0.0935 - val_accuracy: 0.7255
# Epoch 20/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0237 - accuracy: 0.9270
# Epoch 20: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 75ms/step - loss: 0.0237 - accuracy: 0.9270 - val_loss: 0.0927 - val_accuracy: 0.7171
# Epoch 21/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9308
# Epoch 21: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 74ms/step - loss: 0.0226 - accuracy: 0.9308 - val_loss: 0.0955 - val_accuracy: 0.7190
# Epoch 22/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0223 - accuracy: 0.9323
# Epoch 22: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 74ms/step - loss: 0.0223 - accuracy: 0.9323 - val_loss: 0.0925 - val_accuracy: 0.7232
# Epoch 23/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0216 - accuracy: 0.9333
# Epoch 23: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 72ms/step - loss: 0.0216 - accuracy: 0.9333 - val_loss: 0.0959 - val_accuracy: 0.7227
# Epoch 24/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0226 - accuracy: 0.9292
# Epoch 24: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 73ms/step - loss: 0.0226 - accuracy: 0.9292 - val_loss: 0.0959 - val_accuracy: 0.7158
# Epoch 25/25
# 190/190 [==============================] - ETA: 0s - loss: 0.0213 - accuracy: 0.9339
# Epoch 25: val_accuracy did not improve from 0.72880
# 190/190 [==============================] - 14s 72ms/step - loss: 0.0213 - accuracy: 0.9339 - val_loss: 0.0964 - val_accuracy: 0.7148
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
# Chargement du modèle à partir du fichier spécifié.
model_path = "Model.hdf5"
Classifier : Model = load_model(model_path)


#Utilisation du modèle pour effectuer des prédictions sur l'ensemble de test 
# et Arrondissement des prédictions à la classe la plus probable (0 ou 1 dans le cas d'une classification binaire).
predicted_classes = Classifier.predict(X_test)
predicted_classes = np.round(predicted_classes)

#Calcul et affichage des métriques de performance 
acc=accuracy_score(y_test, predicted_classes)
precision=precision_score(y_test, predicted_classes, average='micro')
recall=recall_score(y_test, predicted_classes, average='micro')
f1=f1_score(y_test, predicted_classes, average='micro')
t=0
f=0
for i in range(len(predicted_classes)):

    if  False in (y_test[i]==predicted_classes[i]):
        f=f+1
    else:
        t=t+1

print("Acc=",acc)
print("precision=",precision)
print("recall=",recall)
print("f1=",f1)
print("************************")
print ((t/len(y_test))*100)
print("**********")
print ((f/len(y_test))*100)


# Cette fonction renvoie les indices des échantillons bien classés pour chaque classe.
# Elle prend en parametre x la liste des classes des donnees de test
# Elle retourne les listes des indices de chaque classe.
def nbMalVal(x):
    Norm=[]
    Mi=[]
    Sttc=[]
    Cd=[]
    Hyp=[]
    for i in range(len(x)):
        if x[i][0]==1:
            Norm.append(i)
        elif x[i][1]==1:
            Mi.append(i)
        elif x[i][2]==1:
            Sttc.append(i)
        elif x[i][3]==1:
            Cd.append(i)
        elif x[i][4]==1:
            Hyp.append(i)

    return Norm, Mi, Sttc, Cd, Hyp


# Cette fonction calcule le pourcentage de prédictions correctes et incorrectes pour une classe donnée.
# Elle prend en parametre Norm la liste d'indice d'une classes .
# Elle retourne le pourcentages de prédictions correctes et incorrectes.
def resultPrct(Norm):
  t=0
  f=0
  for i in range(len(Norm)):
    if  False in (y_test[Norm[i]]==predicted_classes[Norm[i]]):
        f=f+1
    else:
        t=t+1
  true = ((t/len(Norm))*100)
  false= ((f/len(Norm))*100)
  return true, false


# Affichage du pourcentage de prédictions correctes (true) et incorrectes (false) pour chaque classe.
Norm, Mi, Sttc, Cd, Hyp=nbMalVal(y_test)
Nt, Nf = resultPrct(Norm)
Mt, Mf = resultPrct(Mi)
St, Sf = resultPrct(Sttc)
Ct, Cf = resultPrct(Cd)
Ht, Hf = resultPrct(Hyp)
print(Nt, Nf, Mt, Mf, St, Sf, Ct, Cf, Ht,Hf)
# Out:
#  1/68 [..............................] - ETA: 14s
# 2023-09-21 12:43:01.088317: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 68/68 [==============================] - 1s 9ms/step
# Acc= 0.7122335495829472
# precision= 0.7253421425200566
# recall= 0.7122335495829472
# f1= 0.7187280804302081
# ************************
# 71.22335495829472
# **********
# 28.776645041705283
# 88.99273104880582 11.007268951194185 66.72727272727272 33.27272727272727 60.05291005291006 39.94708994708995 39.81042654028436 60.18957345971564 3.571428571428571 96.42857142857143
